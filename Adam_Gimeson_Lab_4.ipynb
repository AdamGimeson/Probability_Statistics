# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamGimeson/Probability_Statistics/blob/main/Adam_Gimeson_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])

# %%
# population

# %%
np.sum(x)
# Out:
# 10

# %%
# The sum of the array

# %%
x.shape[0]
# Out:
# 4

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %%
# the 10(sum) divided by 4(shape)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
mean(x)
# Out:
# 2.5

# %%
#mean is 2.5 (the average)

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
# x is still equal to the orginalarray

# %%
x - mean(x)
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
# x - 2.5(mean) for all numbers in array

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
# the vaule of x - mean multipled by itself

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
# mean of x

# %%
var(x)
# Out:
# 1.25

# %%
#the A measure of spread for a distribution of a random variable that determines the degree to which the values of a random variable differ from the expected value.

# %%
std(x)
# Out:
# 1.118033988749895

# %%
# the square root of the variance of X

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
x = (m * x + b) % n

# %%
#mx*b

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-055536ed35ba> in <module>
#       3     x = (m * x + b) % n
#       4
# ----> 5     X[i] = x
#
# ValueError: setting an array element with a sequence.

# %%
X
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# x is equal to 0 all the way through the array i beleive

# %%
X /= np.max(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
# Im Not sure what this code is but i think it says there is an invalid value

# %%
plt.plot(X[:100],'.')

# %%
# plot with no values

# %%
plt.hist(X);

# %%
# hist plot which is different from the first plot with all values covered

# %%
plt.hist(X,100);

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
# x which is the array of all of these values which are not on the plot

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
# x equals Random numbers

# %%
X
# Out:
# array([0.00776595, 0.22011681, 0.07660271, ..., 0.71878709, 0.83019533,
#        0.82489651])

# %%
plt.hist(X,100);

# %%
#plot of random numbers

# %%
np.random.random()
# Out:
# 0.24419930638594578

# %%
r = np.random.random()

# %%
# r = random number

# %%
r
# Out:
# 0.12912060519391488

# %%
r = np.random.randint(1,10)

# %%
r
# Out:
# 5

# %%
#random number from 1,10 was 5

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors']

# %%
game[r[0]]
# Out:
# 'scissors'

# %%
# random vaule from rock paper sissors game

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (0, 1)

# %%
# generating random point from 0,3

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
# Out:
# ('scissors', 'scissors')

# %%
# creating a point from the game

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# 0.20302116627509245

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
#pattern of the same amount of numbers per number 1 gets 1 2 gets two 2,s ...

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);

# %%
#graph of numbers from 0,100

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()

# %%
# four random plots in different context, shape, but all tell you the same values

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);

# %%
#plot of the x value

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);

# %%
#plot of the x value squared

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.31533866,  58.33504905,  69.35475943,  80.37446981,
#         91.3941802 , 102.41389058, 113.43360096, 124.45331135,
#        135.47302173, 146.49273212, 157.5124425 ])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %%
# line graph of the data above

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.2686375893311

# %%
#value of the mean

# %%
std(x)
# Out:
# 14.966815085663306

# %%
# value of the square root of the variance of X.

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %%
# plotted line graph of the above information

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
# formulas for random number generator

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
#mean of distrubution is 0

# %%
sigma = 1

# %%
# standard devation equals 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')

# %%
#changed plot from line to lots of points some green

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
#not sure about this

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
# I think this is from the above data making sure it is "in range"

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))

# %%
z
# Out:
# array([[[203,  11,   5]]])

# %%
#allowing z be the random variable

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z)

# %%
#color box graph with random colors

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z)

# %%
#correlating points on the graph with a specific color block

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
# all fidderent values for a different color

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  7.,  25.,  89., 184., 243., 201., 149.,  73.,  26.,   3.]),
#  array([-0.01613575,  0.08856139,  0.19325852,  0.29795565,  0.40265279,
#          0.50734992,  0.61204705,  0.71674419,  0.82144132,  0.92613846,
#          1.03083559]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# 0.5230227626940492 0.6073731895998172 0.17611440532363576
# 0.6071821744579398 0.42011822010571837 0.6974642632887376
# 0.33908131080517256 0.5246646940371842 0.465322492227698
# 0.4408025063445502 0.48119042848810184 0.4670107264584597
# 0.4177884200218228 0.2587304689208022 0.7235516558513287
# 0.2470435421003528 0.23903893043472785 0.5193460410047839
# 0.8316473832567626 0.4795307453522252 0.7833130944897166
# 0.6705948632805734 0.6362674894255242 0.3094453604761537
# 0.4070223418489583 0.3173311477119046 0.29777668222831877
# 0.7442218909514827 0.8203291079255792 0.517819469009085
# 0.6606112790093022 0.3478254658569344 0.6455133364806048
# 0.7577580602106191 0.45983456400691364 0.49578685572356573
# 0.27090396392188854 0.6145166327188489 0.4012892707877594
# 0.8051466613129146 0.5660707407377285 0.4284700168465474
# 0.7185293610487112 0.4533983359100685 0.08700974686386426
# 0.4082183930711942 0.34618655041792984 0.32535991536012654
# ...

# %%
# all the values in range(100)

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.9939360578005025 0.8135796797190064 0.10481626598564386
# 0.00813661970084223 0.8259464696943974 0.13875562004523234
# 0.032420098912209094 0.18533720041558066 0.14476329354636164
# 0.5905144600062221 0.5294198072308066 0.08479497047748408
# 0.7907713827177013 0.6333398364513683 0.3031147270496839
# 0.15279381104304657 0.6356746485772958 0.8692538896395864
# 0.6790991458673683 0.3221217907741626 0.6698592869172518
# 0.9205629605196716 0.09468737430246932 0.4967020305570643
# 0.48479009932492134 0.8442708226184358 0.7669340920641781
# 0.7885274490873204 0.39167100401919575 0.2314567499748269
# 0.9677766096934792 0.8015192582142663 0.9230830587858266
# 0.17829610000677054 0.29507902908855266 0.6239174648872647
# 0.5415584314713391 0.4602300962533591 0.38376708659877135
# 0.8677206923466464 0.5670719807377059 0.8340102261183062
# 0.7675298617086419 0.31812423274329316 0.07459914446679916
# 0.8797333027864995 0.01977989331774077 0.41506303357188756
# ...

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
#the stack of random colors coming together

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
#random color generator

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %%
#instead of 5 random colors it is just a row of 2 colors mixed and matched

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
# code for pixel art

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
#graph with color scale to clarify what is what on the graph

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
#target looking graph made of random colors

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
#creating a graph with colored lines

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
#checkers board with two colors
